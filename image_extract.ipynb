# %%
import os, glob, shutil
folder = []
os.chdir('/Users/abhinavsingh/Desktop/ipa_react/processed/')
for file in glob.glob('*'):
    folder.append(file)
#print(folder)
len(folder)
# Out:
# 516

# %%
in_folder = []
os.chdir('/Users/abhinavsingh/Desktop/ipa_react/processed/S20210216015710230409/main/')
for i in glob.glob('*'):
    in_folder.append(i)
#print(in_folder)
len(in_folder)
# Out:
# 12

# %%
# total count the folders inside the given path

# %%
for i in folder:
    route = '/Users/abhinavsingh/Desktop/ipa_react/processed/'+str(i)+'/main/*'
    total = 0
    for file in glob.glob(route):
        total += 1
    print(str(i),':', + total)
# Out:
# S20210817033844459721 : 12
# S20210819015818041717 : 12
# S20210220033755333665 : 12
# S20210820034702361812 : 12
# S20210730002453819350 : 12
# S20210902040740287684 : 12
# S20210818042037577104 : 12
# S20210908012642668825 : 12
# S20210819002852323914 : 12
# S20210820035112182462 : 12
# S20210823040629919352 : 12
# S20210908041340561233 : 12
# S20210825002843828894 : 12
# S20210220131936674819 : 12
# S20210820012144222098 : 12
# S20210903031418481905 : 12
# S20210219001016524528 : 12
# S20210819012021120885 : 12
# S20210907034414809128 : 12
# S20210819005901551826 : 12
# S20210824010940604610 : 12
# S20210901015538295892 : 12
# S20210220092637387363 : 12
# S20210826055216743050 : 12
# S20210902073149500073 : 12
# S20210817231714255957 : 12
# S20210803015159886331 : 12
# S20210906051605392695 : 12
# S20210218042752886688 : 12
# S20210729073727004850 : 12
# S20210218134028449563 : 12
# S20210903035406391454 : 12
# S20210819045932628398 : 12
# S20210729022558892286 : 12
# ...

# %%
# total count the folders inside the path and if the number of folder is not 12 then remove that from the list

# %%
for i in folder:
    route = '/Users/abhinavsingh/Desktop/ipa_react/processed/'+str(i)+'/main/*'
    total = 0
    for file in glob.glob(route):
        total += 1
    if total != 12:
        print('removed :', str(i))
        folder.remove(i)
    else:
        pass
    
    print(str(i), ':', + total)
# Out:
# S20210817033844459721 : 12
# S20210819015818041717 : 12
# S20210220033755333665 : 12
# S20210820034702361812 : 12
# S20210730002453819350 : 12
# S20210902040740287684 : 12
# S20210818042037577104 : 12
# S20210908012642668825 : 12
# S20210819002852323914 : 12
# S20210820035112182462 : 12
# S20210823040629919352 : 12
# S20210908041340561233 : 12
# S20210825002843828894 : 12
# S20210220131936674819 : 12
# S20210820012144222098 : 12
# S20210903031418481905 : 12
# S20210219001016524528 : 12
# S20210819012021120885 : 12
# S20210907034414809128 : 12
# S20210819005901551826 : 12
# S20210824010940604610 : 12
# S20210901015538295892 : 12
# S20210220092637387363 : 12
# S20210826055216743050 : 12
# S20210902073149500073 : 12
# S20210817231714255957 : 12
# S20210803015159886331 : 12
# S20210906051605392695 : 12
# S20210218042752886688 : 12
# S20210729073727004850 : 12
# S20210218134028449563 : 12
# S20210903035406391454 : 12
# S20210819045932628398 : 12
# S20210729022558892286 : 12
# ...

# %%
for i in folder:
    for j in in_folder:
        source = '/Users/abhinavsingh/Desktop/ipa_react/processed/'+str(i)+'/main/'+str(j)+'/'
        destination = '/Users/abhinavsingh/Desktop/image_data/'+str(j)+'/'

        files = os.listdir(source)
  
        for f in files:
            shutil.copy(source + f, destination+ i + f)
